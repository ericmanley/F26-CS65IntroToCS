# %% [markdown]
# # While Loops
# ## CS 65: Introduction to Computer Science I

# %% [markdown]
# ## Today's Agenda
#
# We're going to
# * Introduce `while` loops that allow us to write statements that iterate and repeat
# * Investigate use cases for loops
# * See how to use the Thonny debugger tool to find and fix problems with our code
# * Practice using loops to iterate through lists
#
#
# ## References
#
# Python for Everybody, Chapter 5: https://www.py4e.com/html3/05-iterations
# A Practical Introduction to Python Programming, Chapter 9: https://www.brianheinold.net/python/python_book.html#chapter_whileloops

# %% [markdown]
# ## Repeating code
#
#
# Sometimes we want a section of our code to repeat multiple times. For this we use a __loop__.
#
# The first loop we're going to look at is a `while` loop. Its syntax is a lot like the `if` statement (but there's no else part):
# * keyword `while`
# * condition
# * colon `:`
# * indented block of code
#
# Example: this code prints `Hello!` 5 times. Let's trace it together.

# %%
greeting_counter = 1

while greeting_counter <= 5:
    print("Hello!")
    greeting_counter = greeting_counter + 1
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!

# %% [markdown]
# ## The `+=` operator
#
# Increasing a variable with a line like
#
# `greeting_counter = greeting_counter + 1`
#
# is so common that they give you a shorter way to do
#
# `greeting_counter += 1`
#
# means the same thing: increase `greeting_counter` by 1.
#
# It works for other operators too, like `-=` and `*=`.
#
# So, we could rewrite the loop as

# %%
greeting_counter = 1

while greeting_counter <= 5:
    print("Hello!")
    greeting_counter += 1
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!

# %% [markdown]
# ## Group Exercise: Guess My Number Game
#
# Complete the guess-my-number game Parsons puzzle here: https://ericmanley.github.io/parsons/guess-my-number/
#
# Then copy-and-paste or type the code into Thonny and run it a few times.
#
# **Discuss:**
# * Why do we need the `guess = 0` line?
# * What does `guess != secret_number` mean again?
# * If we wanted to enhance the program so that it kept track of how many guesses it took and then displayed the number of guesses to the user, what lines of code would we need to add?

# %% [markdown]
# ## Input validation
#
# __input validation:__ making sure the user's input makes sense for the program
#
# We can use the same pattern as the guess-the-number loop to make an input-validation loop.

# %%
print("Soccer team registration form")
num_players = 0

while num_players < 11:
    num_players = int(input("How many players on your team (minimum 11)? "))
    
print("Registering team with",num_players,"players...")
# Out:
# Soccer team registration form
# How many players on your team (minimum 11)? 9
# How many players on your team (minimum 11)? 10
# How many players on your team (minimum 11)? 8
# How many players on your team (minimum 11)? 8
# How many players on your team (minimum 11)? 9
# How many players on your team (minimum 11)? 9
# How many players on your team (minimum 11)? 9
# How many players on your team (minimum 11)? 12
# Registering team with 12 players...

# %% [markdown]
# ## Group Exercise: Accumulation
#
# An __accumulator__ variable keeps a running total of something. Loops are good for this too.
#
# The following Parsons program includes an accumulator: https://ericmanley.github.io/parsons/bill-accumulator/
#
# Complete it as a group. Note that it might have some distractor lines of code!
#
# **Discuss:**
# * Which variable is the *accumulator* variable?
# * Why do each of the distractor lines not belong in the solution?

# %% [markdown]
# ## Group Exercise: Fix this program
#
# Run this program in Thonny and discuss what is going wrong. Then fix the program.

# %%
counter = 0
while counter < 10:
    print("counter:",counter)
counter += 1

# %% [markdown]
# ## Thonny Debugger Demo
#
# The Thonny debugger is a helpful tool that allows you to step through your program and watch what's happening as it executes.
#
# Let's look at how to use it now.
#
# You should get in the habit of using the debugger to help identify logic errors in your code.

# %% [markdown]
# ## Tips for writing loops
#
# * Think about what needs to happen before the loop, during each loop __iteration__, and after the loop
# * Think about what condition should make the loop end
# * Make sure there is something that changes inside the loop that will eventually allow the loop's condition to be `False`
# * Set up loop control variables with initial values _before_ the loop
#
# Loops that don't have a way of terminating are called __infinite loops__. If you accidentally do this in Thonny, you can kill the program by hitting the STOP button.

# %% [markdown]
# ## Loops with Lists
#
# Loops are really good for doing things with lists. For example, you use the `len()` function to find out how many items are in a list and then create a count-controlled loop to go through each item in the list, using the counter as the list index. For example, this list will print out all of the values in the rainfall_amounts list.

# %%
rainfall = [0.0, 0.3, 0.71, 0.0, 0.32, 1.1, 0.4]

counter = 0
while counter < len(rainfall):
    print("Day",counter,"had",rainfall[counter],"inches of rainfall.")
    counter += 1
# Out:
# Day 0 had 0.0 inches of rainfall.
# Day 1 had 0.3 inches of rainfall.
# Day 2 had 0.71 inches of rainfall.
# Day 3 had 0.0 inches of rainfall.
# Day 4 had 0.32 inches of rainfall.
# Day 5 had 1.1 inches of rainfall.
# Day 6 had 0.4 inches of rainfall.
