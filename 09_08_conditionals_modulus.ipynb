# %% [markdown]
# # Conditionals and Modulus Division
# ## CS 65: Introduction to Computer Science I

# %% [markdown]
# ## Today's Agenda
#
# We're going to
# * Learn how to read and write code with conditional `if` and `if-else` statements
# * Discuss how the `%` modulus operator works and when to use it
#
# ## References
#
#
# Think Python, Chapter 5: https://greenteapress.com/thinkpython2/html/thinkpython2006.
#
# A Practical Introduction to Python Programming, Chapter 4: https://www.brianheinold.net/python/python_book.html#section_ifstatements_example

# %% [markdown]
# ## For Reference: example code we've worked with recently

# %%
name = input("What is your name?")
credits = int(input("How many college credits have you earned?"))

credits_still_needed = 120 - credits

if credits_still_needed <= 0:
    print("Congrats",name,", you have enough credits to graduate!")
else:
    semesters_left = credits_still_needed // 15
    print(name, ", you should be able to graduate in about",semesters_left,"semesters.")

# %% [markdown]
# ## Group Exercise: Another riff on the pay calculator
#
# Complete the Parsons problem as a group: https://ericmanley.github.io/parsons/overtime-pay-calculator/
#
# **Answer the following question:**
#
# 1. The `if` statement in this program is different than the reference example above. What is the difference, and when do you think it's appropriate to use each variation?
# 2. Proper indentation of code is important in Python. Why are some of the lines after the `if` indented and some aren't in this program?
# 3. Why does `pay` appear on both the left and right of the `=` in one of the lines of code? What does that mean?

# %% [markdown]
# ## Syntax for `if` statements
#
# * keyword `if`
# * a condition
# * colon `:`
# * indented _block_ of code

# %%
total_bill = 35.63
age = float(input("What is your age? "))

if age > 65:
    print("Applying 10% senior discount")
    total_bill = total_bill * 0.9 
    #any indented code only runs
    #when the condition is True
    
#un-indented code runs no matter what
print("Your total bill is", total_bill)
# Out:
# What is your age?  64
# Your total bill is 35.63

# %% [markdown]
# ## Syntax for `if-else` statements
#
# * keyword `if`
# * a condition
# * colon `:`
# * indented block of code
# * keyword `else`
# * colon `:`
# * indented block of code

# %%
height = int(input("Enter your height in inches: "))

if height < 60:
    print("You are not tall enough for this ride.")
else:
    print("You are tall enough for this ride.")
# Out:
# Enter your height in inches:  62
# You are tall enough for this ride.

# %% [markdown]
# ## Boolean type
#
# The __Boolean__ type has two possible values: `True` and `False`

# %%
bool_variable = True

if bool_variable:
    print("The condition it True!")
# Out:
# The condition it True!

# %% [markdown]
# The _condition_ for an `if`/`if-else` statement can be anything that results in a Boolean. An expression, like `height < 60` that results in a Boolean is called a __Boolean expression__.

# %% [markdown]
# ## Some Boolean operators
#
# * `<` less than
# * `>` greater than
# * `<=` less than or equal
#     - note there is no $\leq$ button on your keyboard
# * `>=` greater than or equal
# * `==` equal (comparison)
#     - note that `=` is used for assignment, they're different operators, don't confuse them!
# * `!=` not equal

# %%
secret_number = 7
guess = int(input("Guess a number: "))

if guess == secret_number:
    print("That was right, good guess!")
else:
    print("Wrong!")
# Out:
# Guess a number:  7
# That was right, good guess!

# %%
total_bill = 121.50
party_size = int(input("Enter number of people at the table: "))
non_profit = input("Was this a business lunch for a non-profit organization? ")
 
if non_profit != "yes":
    print("Calculating 6% sales tax.")
    total_bill = total_bill * 1.06
    
if party_size >= 8:
    print("Automatically adding 15% gratuity.")
    total_bill = total_bill * 1.15
    
print("Your total is",total_bill)
# Out:
# Enter number of people at the table:  11
# Was this a business lunch for a non-profit organization?  no
# Calculating 6% sales tax.
# Automatically adding 15% gratuity.
# Your total is 148.10850000000002

# %% [markdown]
# ## Modulo operator
#
# We've seen that `//` performs **integer division** and just gives the *quotient* (i.e. it rounds down)
#
# The `%` operator is the __modulo__ operator - another word for remainder - it will ignore the quotient and just give you the remainder.
#
# <center>
# <div>
# <img src="images/longdivisionexample.png" width="200"/>
# </div>
# </center>

# %%
403 // 24
# Out:
# 16

# %%
403 % 24
# Out:
# 19

# %% [markdown]
# ## When is this useful?
#
# Example: Let's say I need to assign 107 students among 4 different classrooms. How many students should we assign to each classroom?

# %%
num_students = 107
num_classrooms = 4
students_per_classroom = num_students // num_classrooms
leftover_students = num_students % num_classrooms
print("Each classroom should get",students_per_classroom,"students")
print("and",leftover_students,"classroom(s) will each get one extra")
# Out:
# Each classroom should get 26 students
# and 3 classroom(s) will each get one extra

# %% [markdown]
# Modulo is also good if you need to check if a number is even or odd

# %%
print(253 % 2) #odd numbers have a remainder of 1 when divided by 2
# Out:
# 1

# %%
print(254 % 2) #even numbers have a remainder of 0 when divided by 2
# Out:
# 0

# %% [markdown]
# Or, if you want to check if a number is divisible by 4 - say you're checking to see if the year is a presidential election year, Olympic year, leap year, etc., you can see if the result is 0

# %%
print(2024 % 4)
# Out:
# 0

# %% [markdown]
# ## Lab 3
#
# Complete Lab 2 in the course GitHub page, and submit the challenge exercise to CodeGrade as instructed.
