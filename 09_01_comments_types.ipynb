# %% [markdown]
# # First Lab, Comments, Types, and User Input
# ## CS 65: Intro to Computer Science I

# %% [markdown]
# ## Today's Agenda
#
# We're going to
# * Do the first Lab exercise and turn it in for credit
# * Introduce program **comments**
# * Look more closely at **data types** like *int*, *float*, and *string*
# * See how to convert between types, like you need to do when you get *input* from the user
# * Practice getting input and converting between types
#
# ## References
#
#
# Think Python Chatper 2: https://greenteapress.com/thinkpython2/html/thinkpython2003.html

# %% [markdown]
# ## For Reference: example code we've worked with recently

# %%
name = input("What is your name?")
credits = int(input("How many college credits have you earned?"))

credits_still_needed = 120 - credits

if credits_still_needed <= 0:
    print("Congrats",name,", you have enough credits to graduate!")
else:
    semesters_left = credits_still_needed // 15
    print(name, ", you should be able to graduate in about",semesters_left,"semesters.")

# %%
bill = float(input("How much is the bill? "))
num_people = int(input("How many people are there? "))
tip = bill * 0.15
total = bill + tip
per_person_cost = total / num_people
print("The per-person cost is $", per_person_cost)

# %%
avg_gas_estimate = 3.90
round_trip_miles_to_memphis = 1224
vehicle_mpg = 32
gas_cost = avg_gas_estimate * (round_trip_miles_to_memphis/vehicle_mpg)

vacation_days = 8

hotel_nights = vacation_days-1
hotel_per_night_cost = 129
lodging_cost = hotel_nights * hotel_per_night_cost

food_per_person_per_day = 45
num_people = 4
total_food_per_day = food_per_person_per_day*num_people
souvenirs_and_incidentals_per_day = 100
food_and_incidental_cost = vacation_days*(total_food_per_day+souvenirs_and_incidentals_per_day)

graceland_ticket_cost = 190
graceland_cost = num_people * graceland_ticket_cost

vacation_budget = gas_cost + lodging_cost + food_and_incidental_cost + graceland_cost
print("Vacation budget:",vacation_budget)

# %% [markdown]
# ## Lab 1
#
#
#
# You may work on this problem in pairs/groups or individually. Type your code into a file called `yearwithpython.py` in Thonny.
#
# **Exercise:** Your task is to write a program which computes the fraction of the year that you will spend working on Python for this course. To do that, we'll make the following assumptions:
#
# * The "time spent on Python" is defined as the amount of time that it is recommended for students to put into a course.
# * The recommended time to spend on a course is 3 hours outside of class for every hour inside class.
# * A normal semester includes 14 weeks, with 150 minutes of in-class time each week.
# * You can assume the year is a non-leap year, with 365 days.
#
# Your program might start like this:

# %%
num_course_weeks = 14
in_class_minutes_per_week = 150
total_in_class_minutes = num_course_weeks * in_class_minutes_per_week

# %% [markdown]
# You should include a `print` statetment which prints the answer along with text that explains what the number is. For example, something like this:
#
# <p>
# <div>
# <img src="images/ayearwithpythonoutput.png" width="800" />
# </div>
# </p>
#
# And, that's actually the answer you should come up with if you make all the assumptions listed above and you do all the calculations correctly.
#
# Your code should also use at least *two new variables with descriptive variable names*!
#
# When you have it finished, follow the link on Blackboard to sign up on CodeGrade.

# %% [markdown]
# ## Comments: Programming for humans
#
# __Comments:__ elements of a program which are ignored by the interpreter
# * help document how to use the code properly
# * explain what's going on with more complex code
# * cite references
# * temporarily ignore some code
# * anything for the sake of humans (you and others)

# %% [markdown]
# `#` starts a comment - everything on the rest of the line is ignored

# %%
avg_gas_estimate = 3.90  #current price per gallon in Des Moines
round_trip_miles_to_memphis = 1224
vehicle_mpg = 32
gas_cost = avg_gas_estimate * (round_trip_miles_to_memphis/vehicle_mpg)

# %% [markdown]
# ## Multiline comments
#
# Text surrounded by three sets of quotes will all be ignored - spanning multiple lines

# %%
"""
Here are some estimates used to help calculate
the budget for our vacation to Memphis next
spring break.
"""
avg_gas_estimate = 2.70 #current price in Des Moines
round_trip_miles_to_memphis = 1224
vehicle_mpg = 32
gas_cost = avg_gas_estimate * (round_trip_miles_to_memphis/vehicle_mpg)

# %% [markdown]
# ## Common uses

# %%
avg_gas_estimate = 3.90 #current price in Des Moines
round_trip_miles_to_memphis = 1224
vehicle_mpg = 32
gas_cost = avg_gas_estimate * (round_trip_miles_to_memphis/vehicle_mpg)

vacation_days = 8

#camping_nights = 3
#hotel_nights = vacation_days-1-camping_nights
hotel_nights = vacation_days-1
hotel_per_night_cost = 129 #Airbnb near Graceland
lodging_cost = hotel_nights * hotel_per_night_cost

food_per_person_per_day = 45
num_people = 4
total_food_per_day = food_per_person_per_day*num_people
souvenirs_and_incidentals_per_day = 100
food_and_incidental_cost = vacation_days*(total_food_per_day+souvenirs_and_incidentals_per_day)

#TODO: look up cost for a Grizzlies game and see if we can afford it

#https://www.graceland.com/ticket-information
graceland_ticket_cost = 190
graceland_cost = num_people * graceland_ticket_cost,

vacation_budget = gas_cost + lodging_cost + food_and_incidental_cost + graceland_cost
print("Vacation budget:",vacation_budget)

# %% [markdown]
# ## Types
#
# So far, we've seen different kinds of data

# %%
num_students = 42 #whole numbers
avg_gas_estimate = 2.70 #numbers with decimal
print("Hello world!") #text data
# Out:
# Hello world!

# %% [markdown]
# All data has a __type__ which defines what kind of thing it is and what you can do with it.

# %% [markdown]
# ## Names of some types
#
# __integer:__ whole numbers
#
# __floating point:__ numbers with decimal points
#
# __string:__ text data
#
# The `type()` function can be used to tell you what kind of type something is.
#
# Both values and variables can have types.

# %%
type(2.70)
# Out:
# float

# %%
type(avg_gas_estimate)
# Out:
# float

# %%
type("Hello world")
# Out:
# str

# %%
type(num_students)
# Out:
# int

# %% [markdown]
# ## Expressions on strings
#
# We've seen how arithmetic operators work on numerical types like ints and floats.
#
# Strings have their own operators too - and some look like arithmetic operators!

# %%
greeting = "Hello"
name = "Eric"
greeting+name
# Out:
# 'HelloEric'

# %%
greeting-name #not allowed
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# <ipython-input-7-ea5c4b3c4eb7> in <module>
#
# ----> 1 greeting-name #not allowed
#
#
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Can't apply all string operations to numbers
#
# Similarly, you can't do everything with numbers that you can with strings.

# %%
len(name)
# Out:
# 4

# %%
len(num_students)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# <ipython-input-9-5c4b8b950dfb> in <module>
#
# ----> 1 len(num_students)
#
#
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ## Other types we'll see
#
# There are several other built-in types that we'll hear more about later like
#
# __Boolean:__ can have value `True` or `False`
#
# __List:__ for keeping track of a sequence of values

# %%
type(False)
# Out:
# bool

# %%
type([1,2,3])
# Out:
# list

# %% [markdown]
# You can even make your own types or use those that others have created.

# %% [markdown]
# ## User Input
#
# To receive input from the user, use the built-in `input()` function.

# %%
name = input("Enter your name ")
print("Hello",name)
# Out:
# Enter your name Eric
# Hello Eric

# %% [markdown]
# Think about the `name` variable here. What is its type? How would we check?

# %%
type(name)
# Out:
# str

# %% [markdown]
# ## User input example: Fahrenheit to Celsius converter
#
# The formula for converting Fahrenheit temperatures to Celsius is $$C = (F - 32)*\frac{5}{9}$$
#
# We could make this an interactive program with code like this:

# %%
fahrenheit_temp = input("Enter the temperature in Fahrenheit ")
celsius_temp = (fahrenheit_temp-32)*(5/9)
print("That's",celsius_temp,"in Celsius")
# Out:
# Enter the temperature in Fahrenheit 32
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# <ipython-input-3-fc29a04c7392> in <module>
#
#       1 fahrenheit_temp = input("Enter the temperature in Fahrenheit ")
#
# ----> 2 celsius_temp = (fahrenheit_temp-32)*(5/9)
#
#       3 print("That's",celsius_temp,"in Celsius")
#
#
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# Read the error message! It says we can't subract an int from a string. Even though we typed a number, it treated `fahrenheit_temp` as a string.
#
# Unfortunately, that's just the way `input()` works.

# %% [markdown]
# Fortunately, there's another built-in function we can use to convert something to an integer: `int()`

# %%
val = "32"
print( type(val) )
print( type(int(val)) )
# Out:
# <class 'str'>
# <class 'int'>

# %%
fahrenheit_temp_str = input("Enter the temperature in Fahrenheit ")
fahrenheit_temp_int = int(fahrenheit_temp_str)
celsius_temp = (fahrenheit_temp_int-32)*(5/9)
print("That's",celsius_temp,"in Celsius")
# Out:
# Enter the temperature in Fahrenheit 100
# That's 37.77777777777778 in Celsius

# %% [markdown]
# Or, you can do it all in one step like this

# %%
fahrenheit_temp = int( input("Enter the temperature in Fahrenheit ") )
celsius_temp = (fahrenheit_temp-32)*(5/9)
print("That's",celsius_temp,"in Celsius")
# Out:
# Enter the temperature in Fahrenheit 72
# That's 22.22222222222222 in Celsius

# %% [markdown]
# What would happen if the user typed a floating-point value like `72.5`?

# %% [markdown]
# ## Other type conversion functions
#
# Convert to a floating-point type with `float()`
#
# Convert to a string with `str()`

# %%
fahrenheit_temp = float( input("Enter the temperature in Fahrenheit ") )
celsius_temp = (fahrenheit_temp-32)*(5/9)
print("That's",celsius_temp,"in Celsius")
# Out:
# Enter the temperature in Fahrenheit 72.5
# That's 22.5 in Celsius

# %%
target_number = 42
user_input = int( input("Enter a number greater than ",target_number) ) #doesn't work
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# <ipython-input-15-120d707f2722> in <module>
#
#       1 target_number = 42
#
# ----> 2 user_input = int( input("Enter a number greater than ",target_number) ) #doesn't work
#
#
#
# TypeError: raw_input() takes from 1 to 2 positional arguments but 3 were given

# %%
#above code corrected
target_number = 42
user_input = int( input("Enter a number greater than "+str(target_number)+" ") )
# Out:
# Enter a number greater than 42 43

# %% [markdown]
# ## Group Exercise
#
# If we wanted to make this an interactive program, which variables should get their input from the user?
#
# Edit the code to make it happen.

# %%
avg_gas_estimate = 3.90 #current price in Des Moines
round_trip_miles_to_memphis = 1224
vehicle_mpg = 32
gas_cost = avg_gas_estimate * (round_trip_miles_to_memphis/vehicle_mpg)

vacation_days = 8

#camping_nights = 3
#hotel_nights = vacation_days-1-camping_nights
hotel_nights = vacation_days-1
hotel_per_night_cost = 129 #Airbnb near Graceland
lodging_cost = hotel_nights * hotel_per_night_cost

food_per_person_per_day = 45
num_people = 4
total_food_per_day = food_per_person_per_day*num_people
souvenirs_and_incidentals_per_day = 100
food_and_incidental_cost = vacation_days*(total_food_per_day+souvenirs_and_incidentals_per_day)

#TODO: look up cost for a Grizzlies game and see if we can afford it

#https://www.graceland.com/ticket-information
graceland_ticket_cost = 190
graceland_cost = num_people * graceland_ticket_cost,

vacation_budget = gas_cost + lodging_cost + food_and_incidental_cost + graceland_cost
print("Vacation budget:",vacation_budget)
