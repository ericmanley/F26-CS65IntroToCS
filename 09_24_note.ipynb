# %% [markdown]
# # A note for September 24th
# ## CS 65: Introduction to Computer Science I
#
# As a reminder, Professor Manley will not be in class on September 24th. Instead, you should complete **Lab 6** on your own. You are welcome to come to class during the normal time to work on the lab with peers and/or get assistance from the TAs.
